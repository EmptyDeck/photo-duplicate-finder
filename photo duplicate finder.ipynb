# %%
import os
import cv2
import numpy as np
import random
import hashlib
from PIL import Image
from IPython.display import clear_output
import matplotlib.pyplot as plt
import shutil
import uuid  # for random unique suffix if needed

###############################################################################
# 1) LOADING FILES (이미지 + 동영상)
###############################################################################

def load_files(folder_path):
    """
    Recursively loads all image and video file paths from a folder (and subfolders).
    """
    supported_images = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')
    supported_videos = ('.mp4', '.mov', '.avi', '.mkv', '.wmv', '.flv', '.webm')
    
    file_paths = []
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            lower_file = file.lower()
            if lower_file.endswith(supported_images) or lower_file.endswith(supported_videos):
                file_paths.append(os.path.join(root, file))
    
    return file_paths

def is_video_file(filepath):
    ext = os.path.splitext(filepath)[1].lower()
    video_exts = ('.mp4', '.mov', '.avi', '.mkv', '.wmv', '.flv', '.webm')
    return ext in video_exts

def is_image_file(filepath):
    ext = os.path.splitext(filepath)[1].lower()
    image_exts = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')
    return ext in image_exts

###############################################################################
# 2) IMAGE pHash & VIDEO SIGNATURE
###############################################################################

def compute_image_phash(image_path):
    """
    Computes a perceptual hash (pHash) for an image using OpenCV.
    """
    try:
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            return None
        image = cv2.resize(image, (8, 8), interpolation=cv2.INTER_AREA)
        dct = cv2.dct(np.float32(image))
        dct_roi = dct[0:8, 0:8]
        median_val = np.median(dct_roi)
        phash = ''.join('1' if px > median_val else '0'
                        for row in dct_roi for px in row)
        return phash
    except:
        return None

def compute_video_signature(video_path):
    """
    A naive signature for videos:
      - file size (bytes)
      - duration (seconds)
      - pHash of the middle frame
    """
    try:
        file_size = os.path.getsize(video_path)
        
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            return None
        
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        if frame_count > 0 and fps > 0:
            duration = frame_count / fps
        else:
            duration = 0
        
        # Middle frame
        mid_index = int(frame_count // 2)
        cap.set(cv2.CAP_PROP_POS_FRAMES, mid_index)
        ret, frame = cap.read()
        
        if not ret or frame is None:
            # fallback: first frame
            cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
            ret, frame = cap.read()
        cap.release()
        
        if frame is not None:
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            gray = cv2.resize(gray, (8, 8), interpolation=cv2.INTER_AREA)
            dct = cv2.dct(np.float32(gray))
            dct_roi = dct[0:8, 0:8]
            median_val = np.median(dct_roi)
            phash = ''.join('1' if px > median_val else '0'
                            for row in dct_roi for px in row)
        else:
            phash = None
        
        return {
            'size': file_size,
            'duration': duration,
            'frame_phash': phash
        }
    except:
        return None

def compute_file_signature(filepath):
    """
    For images, returns { 'type': 'image', 'hash': <pHash>, 'size': <bytes> }
    For videos, returns { 'type': 'video', 'size': <bytes>, 'duration': <float>, 'frame_phash': <hash> }
    """
    if is_image_file(filepath):
        phash = compute_image_phash(filepath)
        size = os.path.getsize(filepath)
        return {
            'type': 'image',
            'hash': phash,
            'size': size
        }
    elif is_video_file(filepath):
        vinfo = compute_video_signature(filepath)
        if vinfo is None:
            return None
        return {
            'type': 'video',
            'size': vinfo['size'],
            'duration': vinfo['duration'],
            'frame_phash': vinfo['frame_phash']
        }
    else:
        return None

###############################################################################
# 3) SHA-256 CHECK & SIMILARITY CALC
###############################################################################

def hamming_distance(h1, h2):
    if not h1 or not h2:
        return 64
    return sum(ch1 != ch2 for ch1, ch2 in zip(h1, h2))

def compute_sha256(file_path, chunk_size=65536):
    """
    Computes SHA-256 hash for the file to check if bit-for-bit identical.
    """
    sha = hashlib.sha256()
    try:
        with open(file_path, 'rb') as f:
            while True:
                data = f.read(chunk_size)
                if not data:
                    break
                sha.update(data)
        return sha.hexdigest()
    except:
        return None

def get_similarity(sig1, sig2, path1, path2, check_threshold):
    """
    1) If same type (image-image or video-video), do a pHash-based (or video-based) comparison
    2) If < check_threshold but file sizes are identical => do SHA-256 check => if identical, treat as 100%.
    3) If different types => 0%
    """
    if not sig1 or not sig2:
        return 0.0
    
    if sig1['type'] != sig2['type']:
        return 0.0
    
    # Image vs Image
    if sig1['type'] == 'image' and sig2['type'] == 'image':
        dist = hamming_distance(sig1['hash'], sig2['hash'])
        phash_sim = (64 - dist) / 64 * 100
        if phash_sim >= check_threshold:
            return phash_sim
        else:
            # fallback: file size same => check SHA
            if sig1['size'] == sig2['size']:
                sha1 = compute_sha256(path1)
                sha2 = compute_sha256(path2)
                if sha1 and sha2 and sha1 == sha2:
                    return 100.0
            return phash_sim
    
    # Video vs Video
    if sig1['type'] == 'video' and sig2['type'] == 'video':
        ph1 = sig1.get('frame_phash')
        ph2 = sig2.get('frame_phash')
        if ph1 and ph2:
            dist = hamming_distance(ph1, ph2)
            frame_sim = (64 - dist) / 64 * 100
        else:
            frame_sim = 0
        
        size1, size2 = sig1['size'], sig2['size']
        dur1, dur2 = sig1.get('duration', 0), sig2.get('duration', 0)
        
        # size similarity
        if size1 == 0 or size2 == 0:
            size_similarity = 0
        else:
            size_diff = abs(size1 - size2)
            max_size = max(size1, size2)
            size_penalty = (size_diff / max_size) * 100
            size_similarity = 100 - size_penalty
            if size_similarity < 0:
                size_similarity = 0
        
        # duration similarity
        if dur1 == 0 or dur2 == 0:
            dur_similarity = 0
        else:
            dur_diff = abs(dur1 - dur2)
            max_dur = max(dur1, dur2)
            dur_penalty = (dur_diff / max_dur) * 100
            dur_similarity = 100 - dur_penalty
            if dur_similarity < 0:
                dur_similarity = 0
        
        combined_sim = (frame_sim + size_similarity + dur_similarity) / 3
        
        if combined_sim >= check_threshold:
            return combined_sim
        else:
            if size1 == size2 and size1 != 0:
                sha1 = compute_sha256(path1)
                sha2 = compute_sha256(path2)
                if sha1 and sha2 and sha1 == sha2:
                    return 100.0
            return combined_sim
    
    return 0.0

###############################################################################
# 4) QUALITY + TIE-BREAK (NAME POLICY)
###############################################################################

def get_file_quality(sig):
    """
    Images => file size
    Videos => file_size + 1000 * duration
    """
    if not sig:
        return 0
    if sig['type'] == 'image':
        return sig['size']
    elif sig['type'] == 'video':
        return sig['size'] + 1000 * sig.get('duration', 0)
    return 0

def is_original_name(filename):
    """
    Returns True if there's *no* sign of copy (like (1), 복사본, copy, etc.)
    """
    lower = filename.lower()
    # If "copy" or "복사본" is in name => false
    if "copy" in lower or "복사본" in lower:
        return False
    # If there's a parenthesis with number => likely a copy
    if "(" in lower and ")" in lower:
        return False
    
    return True

def pick_lower_quality_or_tiebreak(path1, path2, sig1, sig2):
    """
    If qualities differ => remove the lower one.
    If tie => keep the file that looks like the 'original' name, otherwise random.
    """
    q1 = get_file_quality(sig1)
    q2 = get_file_quality(sig2)
    
    if q1 < q2:
        return path1
    elif q2 < q1:
        return path2
    else:
        # tie => check name
        orig1 = is_original_name(os.path.basename(path1))
        orig2 = is_original_name(os.path.basename(path2))
        if orig1 and not orig2:
            return path2
        elif orig2 and not orig1:
            return path1
        else:
            return random.choice([path1, path2])

###############################################################################
# 5) MOVING DUPLICATES INSTEAD OF DELETING
###############################################################################

def move_file_to_duplicates(file_path, duplicates_folder):
    """
    Moves the file to the 'duplicates_folder'. 
    If there's a collision, we append a random suffix to the filename.
    """
    if not os.path.exists(duplicates_folder):
        os.makedirs(duplicates_folder, exist_ok=True)
    
    filename = os.path.basename(file_path)
    destination = os.path.join(duplicates_folder, filename)
    
    # If a file with the same name already exists in duplicates_folder, rename
    if os.path.exists(destination):
        # E.g., insert a unique suffix: "filename (uuid4).ext"
        name, ext = os.path.splitext(filename)
        new_filename = f"{name} ({uuid.uuid4().hex[:6]}){ext}"
        destination = os.path.join(duplicates_folder, new_filename)
    
    shutil.move(file_path, destination)
    print(f"Moved => {destination}")

###############################################################################
# 6) MAIN LOGIC: DETECT & MOVE DUPLICATES
###############################################################################

def get_video_frame(video_path, fraction=0.5):
    """
    Extract a frame at 'fraction' (0..1) of the video length for display
    """
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        return None
    frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    target = int(frame_count * fraction)
    cap.set(cv2.CAP_PROP_POS_FRAMES, target)
    ret, frame = cap.read()
    cap.release()
    if not ret:
        return None
    return frame

def show_files_side_by_side(path1, path2, sig1, sig2, similarity):
    clear_output(wait=True)
    
    print(f"Similarity = {similarity:.2f}%")
    print(f"File 1: {os.path.basename(path1)}  ({sig1['type']})")
    print(f"File 2: {os.path.basename(path2)}  ({sig2['type']})\n")
    
    if sig1['type'] == 'image' and sig2['type'] == 'image':
        img1 = Image.open(path1)
        img2 = Image.open(path2)
        
        fig, axes = plt.subplots(1, 2, figsize=(8, 4))
        axes[0].imshow(img1)
        axes[0].set_title(os.path.basename(path1))
        axes[0].axis('off')
        
        axes[1].imshow(img2)
        axes[1].set_title(os.path.basename(path2))
        axes[1].axis('off')
        plt.show()
    
    elif sig1['type'] == 'video' and sig2['type'] == 'video':
        frame1 = get_video_frame(path1, 0.5)
        frame2 = get_video_frame(path2, 0.5)
        
        fig, axes = plt.subplots(1, 2, figsize=(8, 4))
        if frame1 is not None:
            axes[0].imshow(cv2.cvtColor(frame1, cv2.COLOR_BGR2RGB))
        axes[0].set_title(os.path.basename(path1))
        axes[0].axis('off')
        
        if frame2 is not None:
            axes[1].imshow(cv2.cvtColor(frame2, cv2.COLOR_BGR2RGB))
        axes[1].set_title(os.path.basename(path2))
        axes[1].axis('off')
        plt.show()

def detect_and_move_duplicates(folder_path, check_threshold=95.0, delete_threshold=99.0):
    """
    - Scans the folder for images & videos, building signatures
    - Pairwise compares them (O(n^2))
    - If similarity >= delete_threshold => auto-move to 'duplicated_photos'
    - If check_threshold <= similarity < delete_threshold => show user & ask
      (options: y => move one file, n => keep, 1 => stop)
    - If < check_threshold => skip
    - Stats at the end
    """
    all_files = load_files(folder_path)
    total_files = len(all_files)
    
    # Build signatures
    signatures = {}
    for f in all_files:
        signatures[f] = compute_file_signature(f)
    
    # Stats
    stats = {
        'total_files': total_files,
        'pairs_compared': 0,
        'duplicates_auto_moved': 0,
        'duplicates_user_moved': 0,
        'pairs_prompted': 0,
        'pairs_skipped': 0,
        'pairs_under_threshold': 0
    }
    
    file_list = list(signatures.keys())
    checked_pairs = set()
    user_stopped = False
    
    # We'll move duplicates to a subfolder "duplicated_photos" inside folder_path
    duplicates_folder = os.path.join(folder_path, "duplicated_photos")
    
    for i in range(len(file_list)):
        if user_stopped:
            break
        for j in range(i+1, len(file_list)):
            if user_stopped:
                break
            
            path1 = file_list[i]
            path2 = file_list[j]
            
            if (path1, path2) in checked_pairs or (path2, path1) in checked_pairs:
                continue
            checked_pairs.add((path1, path2))
            
            # If one was already moved (i.e. not in signatures anymore), skip
            if path1 not in signatures or path2 not in signatures:
                continue
            
            sig1 = signatures[path1]
            sig2 = signatures[path2]
            stats['pairs_compared'] += 1
            
            if not sig1 or not sig2:
                continue
            
            similarity = get_similarity(sig1, sig2, path1, path2, check_threshold)
            
            if similarity >= delete_threshold:
                # auto-move
                to_move = pick_lower_quality_or_tiebreak(path1, path2, sig1, sig2)
                print(f"[AUTO] {similarity:.2f}% => Moving to duplicates folder: {to_move}")
                move_file_to_duplicates(to_move, duplicates_folder)
                signatures.pop(to_move, None)
                stats['duplicates_auto_moved'] += 1
            
            elif similarity >= check_threshold:
                # prompt user
                stats['pairs_prompted'] += 1
                show_files_side_by_side(path1, path2, sig1, sig2, similarity)
                
                print("Options: [y] move one file, [n] keep both, [1] stop now")
                choice = input("Choice: ").strip().lower()
                
                if choice == 'y':
                    to_move = pick_lower_quality_or_tiebreak(path1, path2, sig1, sig2)
                    print(f"[USER] {similarity:.2f}% => Moving: {to_move}")
                    move_file_to_duplicates(to_move, duplicates_folder)
                    signatures.pop(to_move, None)
                    stats['duplicates_user_moved'] += 1
                elif choice == 'n':
                    print("[SKIPPED] Kept both.\n")
                    stats['pairs_skipped'] += 1
                elif choice == '1':
                    print("Stopping per user request...")
                    user_stopped = True
                    break
                else:
                    # treat as 'n'
                    print("[SKIPPED] Kept both.\n")
                    stats['pairs_skipped'] += 1
            
            else:
                stats['pairs_under_threshold'] += 1
                # skip
    
    total_moved = stats['duplicates_auto_moved'] + stats['duplicates_user_moved']
    files_remaining = total_files - total_moved
    duplicates_found = total_moved + stats['pairs_skipped']
    
    print("\n===== RUN SUMMARY =====")
    print(f"Total files scanned: {stats['total_files']}")
    print(f"Total pairs compared: {stats['pairs_compared']}")
    print(f"Pairs < {check_threshold}% similarity: {stats['pairs_under_threshold']}")
    print(f"Pairs prompted (≥ {check_threshold}% & < {delete_threshold}%): {stats['pairs_prompted']}")
    print(f"  - Duplicates user moved: {stats['duplicates_user_moved']}")
    print(f"  - Pairs user skipped (kept both): {stats['pairs_skipped']}")
    print(f"Pairs auto-moved (≥ {delete_threshold}%): {stats['duplicates_auto_moved']}")
    print(f"Total duplicates found (any ≥ {check_threshold}%): {duplicates_found}")
    print(f"Total files moved: {total_moved}")
    print(f"Files still remaining in original location: {files_remaining}")
    if user_stopped:
        print("User stopped before checking all pairs.")
    else:
        print("Completed all comparisons.")

def main():
    """
    Example usage with user input for folder path.
    """
    folder_path = input("Put the folder directory here: ")
    detect_and_move_duplicates(folder_path, check_threshold=96.86, delete_threshold=96.87)

main()  # Uncomment to run if you're in a normal Python environment
# Out:
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_
jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_1167 (66169e) (2b5f33).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3023 (1) (e01031).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3023 (1) (e01031) (07f08b).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3023 (e85319).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3023 (e85319) (79e84c).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3025 (0d9335).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3025 (0d9335) (de56cf).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3025 (1) (84673c).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_3025 (1) (84673c) (2931bd).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_0755 (6345a8).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_0755 (6345a8) (b6b19e).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_0767 (e78c22).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_0767 (e78c22) (6ef143).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_1160 (b9e175).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_1160 (b9e175) (b7e6b6).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_0787 (c1bb1f).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_0787 (c1bb1f) (5d86b7).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_1166 (3b6eab).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_1166 (3b6eab) (f20443).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8506 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8506 (1) (176ecb).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8506.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8506 (00d011).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8507 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8507 (1) (e33d58).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8507 (2).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8507 (2) (5c7c87).JPG
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8507.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8507 (3edc00).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8508 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8508 (1) (00bdce).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8508.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8508 (3c8ba8).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8509 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8509 (1) (8aa1e7).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8509.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8509 (8c502e).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8510 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8510 (1) (5b567a).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8510.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8510 (deddc6).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8511 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8511 (1) (5ef6a0).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8511.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8511 (7ac47c).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8511 (2).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8511 (2) (396d03).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8512 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8512 (1) (f7946b).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8512 (2).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8512 (2) (1ea53a).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8512.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8512 (f767c5).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8513 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8513 (1) (22b5a2).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8513.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8513 (1317e4).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8518 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8518 (1) (175b78).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8518.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8518 (6db74c).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8519 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8519 (1) (c935eb).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8519.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8519 (ff4873).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8522 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8522 (1) (4d3f86).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8522.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8522 (e9b339).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8523 (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8523 (1) (6bcedd).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8523.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8523 (744ba9).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8531.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8531 (903b7e).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8615.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8615 (991a97).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8725.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_8725 (cbb561).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_5914 (808fb1).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_5914 (808fb1) (ee2b5d).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\lp_image (1).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (1).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6417 (80fb28).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6417 (80fb28) (6417ab).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6373 (29869d).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6373 (29869d) (370a16).JPG
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6375 (69718c).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6375 (69718c) (9d5c30).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6459 (fa4c62).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6459 (fa4c62) (d632ae).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6460 (3d0809).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6460 (3d0809) (27e758).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_5920 (e6c99c).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_5920 (e6c99c) (6eb325).JPG
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (4).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (4) (91b4a0).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (5).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (5) (069a3d).jpg
# [AUTO] 96.88% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image.jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (a1ef0b).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_5962 (fe1ee2).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_5962 (fe1ee2) (40c158).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (6).jpg
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\lp_image (6) (3ad685).jpg
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6372 (ac4764).JPG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6372 (ac4764) (0997f6).JPG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_4834 (de64ba).JPEG
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_4834 (de64ba) (427509).JPEG
# [AUTO] 100.00% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6460 (e1ea2c).MOV
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_6460 (e1ea2c) (4b87d8).MOV
# [AUTO] 97.33% => Moving to duplicates folder: C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_7818.MOV
# Moved => C:\Users\sejik\Desktop\photos\shared folder\duplicated_photos\IMG_7818 (8115f7).MOV
#
# ===== RUN SUMMARY =====
# Total files scanned: 5014
# Total pairs compared: 7800745
# Pairs < 96.86% similarity: 7798864
# Pairs prompted (≥ 96.86% & < 96.87%): 0
#   - Duplicates user moved: 0
#   - Pairs user skipped (kept both): 0
# Pairs auto-moved (≥ 96.87%): 1881
# Total duplicates found (any ≥ 96.86%): 1881
# Total files moved: 1881
# Files still remaining in original location: 3133
# Completed all comparisons.

# %% [markdown]
# # READ ME!
# ## This is a code that findes duplicates and moves all of it in a folder
# ### if the photos Similarity is higher then delete_threshold , it automaticly moves it
# ### if its higher then check_threshold, it lets you check
